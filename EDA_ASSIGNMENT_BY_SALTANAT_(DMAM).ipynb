# %% [markdown]
# <a href="https://colab.research.google.com/github/SaLTanaTuruz/DEMO/blob/main/EDA_ASSIGNMENT_BY_SALTANAT_(DMAM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA

# %% [markdown]
# Hi everyone, This is your first assignment for week 1...
# So in this assignment you have to perform EDA on the below dataset.
# The problem statements are given below.
# Just write a code for them...

# %%
# !wget https://www.kaggle.com/datasets/aestheteaman01/zomato-restaurants-in-delhi-ncr
# Out:
# --2023-09-10 10:07:54--  https://www.kaggle.com/datasets/aestheteaman01/zomato-restaurants-in-delhi-ncr
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘zomato-restaurants-in-delhi-ncr’
#
# zomato-restaurants-     [ <=>                ]  15.94K  --.-KB/s    in 0.02s
#
# 2023-09-10 10:07:54 (716 KB/s) - ‘zomato-restaurants-in-delhi-ncr’ saved [16322]

# %%
import pandas as pd

# %%
restaurants=pd.read_csv("restaurants.csv")

# %%
restaurants
# Out:
#              Restaurant_Name  \
# 0                   Rustom's
# 1                  Cafe Lota
# 2     Dum-Pukht - ITC Maurya
# 3                Burma Burma
# 4              The Big Chill
# ...                      ...
# 1960          Bablu Chic-Inn
# 1961               Kovilakam
# 1962        Krips Restaurant
# 1963                Cafe 147
# 1964                Pizzasia
#
#                                                Category  Pricing_for_2  \
# 0     Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1           Cafe, South Indian, North Indian, Beverages           1200
# 2                       Mughlai, North Indian, Desserts           5000
# 3           Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                        Continental, American, Italian           1500
# ...                                                 ...            ...
# 1960          Mughlai, North Indian, Chinese, Fast Food            500
# ...

# %% [markdown]
# # ***Q1.Are there any null values in the dataset?if yes then fill them..***

# %%
restaurants.isna().sum()
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating          402
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2               405
# Known_For22              841
# dtype: int64

# %%
#yes,there are null values

# %%
mean=restaurants["Delivery_Rating"].mean

# %%
restaurants["Delivery_Rating"]=restaurants["Delivery_Rating"].fillna(mean)

# %%
restaurants.isna().sum()
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating            0
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2               405
# Known_For22              841
# dtype: int64

# %%
restaurants['Known_For2'].unique()
# Out:
# array([nan,
#        'Pondicherry Fish Curry, Coconut Rabdi, Sabudana Pop Corn, Chicken Pasanda, Majestic Chicken, Bhapa Doi',
#        'Royal ambiance and Mughlai cuisine, also received the "Times Food Award 2015" for Culinary Heritage',
#        ...,
#        'Excellent Food, Good Ambience, Courteous Staff, Awesome Food, Great Food, Ambiance',
#        'Pool, Live Music, Cafe, Environment, Good Place, Staff',
#        'Cordial Staff, Great Recommendations, Mouth Watering Food, Reasonable Prices, Quantity, Ambience'],
#       dtype=object)

# %%
restaurants['Known_For2'].value_counts()
# Out:
# Get a complimentary night, earn up to 50% of spends as points at 250+ restaurants & much more. Know more    15
# Finger Food, Continental, Mediterranean, Italian, Asian                                                      9
# Continental, Italian, Fast Food, North Indian, Beverages, Coffee                                             7
# Chinese, Asian, Continental, North Indian, Beverages                                                         2
# Butterscotch Pastry, Truffle Pastry, Chocolate Truffle Cake, Pastries, Waffle, Cakes                         2
#                                                                                                             ..
# Passion Fruit Ice Tea, Cardamom Tea, Bun Tikki, Earl Grey Tea, Rose Tea, Smoked Chicken Pasta                1
# Chicken Crostini, Blackberry Mojito, Butter Maggi, Peri Fries, Masala Tea, Hot Coffee                        1
# ...

# %%
restaurants['Known_For2']=restaurants['Known_For2'].fillna("Get a complimentary night, earn up to 50% of spends as points at 250+ restaurants & much more. Know more")

# %%
restaurants.isna().sum()
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating            0
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2                 0
# Known_For22              841
# dtype: int64

# %%
restaurants['Known_For22'].value_counts()
# Out:
# Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality                     2
# Artistic Decor, The Service, Natural Ambience, Fusion Menu, Serene Ambience, Fusion Food                               1
# Excellent Place, Great Value, Nice Service, Recommended Place, Good Quality Food, Amazing Taste                        1
# Amazing Food and Experience, Delivery Instructions, Genuine Price, Faster Delivery, Worth the Price, Food Packaging    1
# Budget Food, Good for Large Groups, Packed on Weekends, Portions, Good Taste, Main Course                              1
#                                                                                                                       ..
# Classy Decor, Wonderful Service, Chinese, Server, Excellent Food, Hospitality                                          1
# Pocket Friendly, Nice Crowd, Great Ambiance, Polite Staff, Prompt Service, Worth the Money                             1
# ...

# %%
restaurants['Known_For22']=restaurants['Known_For22'].fillna("Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality  ")

# %%
restaurants.isna().sum()
# Out:
# Restaurant_Name          0
# Category                 0
# Pricing_for_2            0
# Locality                 0
# Dining_Rating            0
# Dining_Review_Count      0
# Delivery_Rating          0
# Delivery_Rating_Count    0
# Website                  0
# Address                  0
# Phone_No                 0
# Latitude                 0
# Longitude                0
# Known_For2               0
# Known_For22              0
# dtype: int64

# %%
restaurants
# Out:
#              Restaurant_Name  \
# 0                   Rustom's
# 1                  Cafe Lota
# 2     Dum-Pukht - ITC Maurya
# 3                Burma Burma
# 4              The Big Chill
# ...                      ...
# 1960          Bablu Chic-Inn
# 1961               Kovilakam
# 1962        Krips Restaurant
# 1963                Cafe 147
# 1964                Pizzasia
#
#                                                Category  Pricing_for_2  \
# 0     Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1           Cafe, South Indian, North Indian, Beverages           1200
# 2                       Mughlai, North Indian, Desserts           5000
# 3           Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                        Continental, American, Italian           1500
# ...                                                 ...            ...
# 1960          Mughlai, North Indian, Chinese, Fast Food            500
# ...

# %% [markdown]
# # ***Q2.Which restaurant is the best one having ratings more than 4.5 for delivery***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
restaurants['Delivery_Rating']
# Out:
# 0                                                     4.4
# 1                                                     3.9
# 2       <bound method NDFrame._add_numeric_operations....
# 3                                                     4.4
# 4       <bound method NDFrame._add_numeric_operations....
#                               ...
# 1960                                                  4.1
# 1961    <bound method NDFrame._add_numeric_operations....
# 1962                                                  3.9
# 1963                                                  3.8
# 1964                                                  3.9
# Name: Delivery_Rating, Length: 1965, dtype: object

# %%
S=restaurants['Delivery_Rating'].value_counts()
S
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0       4.4\n1       3.9\n2       NaN\n3       4.4\n4       NaN\n       ... \n1960    4.1\n1961    NaN\n1962    3.9\n1963    3.8\n1964    3.9\nName: Delivery_Rating, Length: 1965, dtype: float64>    402
# 3.9                                                                                                                                                                                                                                                                   304
# 4.0                                                                                                                                                                                                                                                                   264
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
plt.plot(['Delivery_Rating'],['Restaurant_Name'],marker="*")
plt.xlabel("Ratings")
plt.ylabel("Restaurant_Name")
plt.show()

# %%
restaurants["Delivery_Rating"]
# Out:
# 0                                                     4.4
# 1                                                     3.9
# 2       <bound method NDFrame._add_numeric_operations....
# 3                                                     4.4
# 4       <bound method NDFrame._add_numeric_operations....
#                               ...
# 1960                                                  4.1
# 1961    <bound method NDFrame._add_numeric_operations....
# 1962                                                  3.9
# 1963                                                  3.8
# 1964                                                  3.9
# Name: Delivery_Rating, Length: 1965, dtype: object

# %%
# I think there are zero restaurants who are having rating greater than 4.5

# %% [markdown]
# # ***Q3.What type of food is most preffered by the customers?***

# %%
restaurants["Category"].value_counts()
# Out:
# North Indian                                                      88
# North Indian, Chinese                                             39
# North Indian, Mughlai                                             37
# Pizza, Fast Food                                                  19
# North Indian, Chinese, Mughlai                                    17
#                                                                   ..
# North Indian, Kebab, Mughlai, Biryani, Beverages                   1
# North Indian, Continental, Italian, Chinese                        1
# North Indian, Continental, Asian, Chinese                          1
# Afghan, Iranian, Awadhi, Beverages                                 1
# Cafe, North Indian, Chinese, Kashmiri, Rolls, Pizza, Beverages     1
# Name: Category, Length: 1355, dtype: int64

# %%
#NORTH INDIAN types of food are prefered by the customers🙃

# %% [markdown]
# # ***Q4.How many people prefer delivery rather than dining ?***

# %%
sns.countplot(x=restaurants['Dining_Review_Count'])
# Out:
# <Axes: xlabel='Dining_Review_Count', ylabel='count'>

# %%
p=restaurants['Dining_Review_Count'].sum()
p
# Out:
# 1418640

# %%
q=restaurants['Delivery_Rating_Count'].sum()
q
# Out:
# 5953067

# %%
q-p
# Out:
# 4534427

# %%
# 4534427 prefer delivery rather than dinning.

# %% [markdown]
# # ***Q5.Which restaurant is the best one having ratings more than 4.5 for dining?***

# %%
b=restaurants['Restaurant_Name'][(restaurants['Dining_Rating']>=4.5)]
c=restaurants[['Restaurant_Name','Dining_Review_Count']][(restaurants['Dining_Rating']>=4.5)].sort_values('Dining_Review_Count')
c
# Out:
#                           Restaurant_Name  Dining_Review_Count
# 42                     Echoes Living Room                    3
# 165                   Only Bar Restaurant                   91
# 93                                   Rooh                  247
# 152  The Haven International Coffee House                  282
# 158                         Little Saigon                  440
# ..                                    ...                  ...
# 89                   The Drunken Botanist                 6302
# 4                           The Big Chill                 6487
# 20                                 Gulati                 6509
# 51              AB's - Absolute Barbecues                 8002
# 54                        Saravana Bhavan                 8305
#
# [166 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...

# %%
# Saravana Bhavan	has highest rating more than 4.5 for dining.

# %% [markdown]
# # Q**6.Compare different delivery rating counts of different restaurants.**
# # Also tell that which restaurants has got the highest rating counts.
# # Do this by creating a barplot **

# %%
restaurants["Delivery_Rating_Count"].value_counts()
# Out:
# 0       256
# 1        33
# 3        22
# 2        20
# 4        13
#        ...
# 792       1
# 7998      1
# 4757      1
# 1628      1
# 5196      1
# Name: Delivery_Rating_Count, Length: 1222, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(30,10))

restaurants['Delivery_Rating_Count'].value_counts().plot(kind='bar')
plt.ylabel=("restaurants name")
plt.xlabel=("delivery_rating_counts")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x='Restaurant_Name',y='Delivery_Rating_Counts',restaurants=restaurants).
plt.show()
# Out:
#   File "<ipython-input-60-e43a962452b2>", line 2
#     sns.barplot(x='Restaurant_Name',y='Delivery_Rating_Counts',restaurants=restaurants).
#                                                                                         ^
# SyntaxError: invalid syntax
